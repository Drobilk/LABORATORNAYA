# %% [markdown]
# # № 3.2.8
#
# Составьте программу, которая запрашивает название государства и его столицы, а затем выводит сообщение:

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_03_02_08.
#
# Выполнил: Кахуджи Д.Т.
# Группа: Адеу201
# E-mail: !!!


# Название государства
country = input(" Введите название государства: ")# Удалите комментарий и допишите код
# Название столицы
capital =input(" Введите название столицы: ") # Удалите комментарий и допишите код

print(" Введите название государства " + " - " + country + "," + " Введите название столицы " + " - " + capital) # Удалите комментарий и допишите код (используйте format() для вывода))


# --------------
# Пример вывода:
#
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва
# Out:
#  Введите название государства: ОАЭ
#  Введите название столицы: Абу-Даби
#  Введите название государства  - ОАЭ, Введите название столицы  - Абу-Даби
