# %% [markdown]
# # № 3.2.9
#
# Дано слово объектно-ориентированный. Используя индексацию и срезы составьте из него слова объект, ориентир, тир, кот, рента и выведите их на экран.

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_03_02_09.
#
# Выполнил: Кахуджи Д.Т.
# Группа: АДЕУ201
# E-mail: !!!


word = "объектно-ориентированный"

w1 = word[:6]  # (слово объект)
w2 = word[9:17] # Удалите комментарий и допишите код (слово ориентир)
w3 = word[14:17]# Удалите комментарий и допишите код (слово тир)
w4 = word[4] + word[0] + word[5] # Удалите комментарий и допишите код (слово кот)
w5 = word[10] + word[3] + word[6] + word[5] + word[19]
# Удалите комментарий и допишите код (слово рента)

print(w1, w2, w3, w4, w5, sep="\n")


# --------------
# Пример вывода:
#
# объект
# ориентир
# тир
# кот
# рента
# Out:
# объект
# ориентир
# тир
# кот
# рента
